# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # INFORMACIÓN DEL PROYECTO

# %% [markdown]
# ### TÍTULO

# %% [markdown]
# # Pokemón

# %% [markdown]
# ### Preparandonos para el competitivo!

# %%
# Describe brevemente el tema del proyecto en Markdown
tema = "Estudio de la competitividad de los pokemon más conocidos"

# %% [markdown]
# ### HIPÓTESIS

# %% [markdown]
# Define aquí lo que será la hipótesis de tu proyecto.
# Deberás tener más de una, pero tu proyecto lo harás teniendo una principal hipótesis.

# %%
# Escribe tu hipótesis principal en Markdown
#hipotesis_1 = "¿Es Pikachu, un pokemon apto para competitivo?, ¿sería mejor su evolucion?"

# %%
# Escribe más hipótesis si las hubiera en Markdown
# hipotesis_2 = ""Analisis del tipo dragon respecto al resto?""
# hipotesis_3 = ""Analisis de Charizard""
# hipotesis_4 = ""Analisis de Gyarados""
# hipotesis_5 = " Analisis de Mewtwo "
# ...

# %% [markdown]
# ## OBTENCIÓN DE LOS DATOS

# %% [markdown]
# ### DATASETS Y FUENTES ALTERNATIVAS DE DATOS

# %% [markdown]
# Incluye aquí una vista del dataset o datasets de los que partirás para poder evaluar tu hipótesis. <br>
# También incluye el origen de estos datos y su fuente.

# %%
import pandas as pd
import numpy as np
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt
import statistics
import warnings
# guarda en variables los datasets y su fuente
#df_1 = pd.DataFrame()
# fuente_1 = ""
# df_2 = pd.DataFrame()
# fuente_2 = ""
# df_3 = pd.DataFrame()
# fuente_3 = ""
# df_4 = pd.DataFrame()
# fuente_4 = ""
# df_5 = pd.DataFrame()
# fuente_5 = ""
# ...

# %%
warnings.filterwarnings("ignore")

# %% [markdown]
# Muestra mediante un head() los principales datasets con los que vas a trabajar

# %%
archivo = "data/Pokemon.csv"
pokemon = pd.read_csv(archivo, index_col=0)

# %%
# Primer dataset
pokemon.head(10)
# Out:
#                         Name Type 1  Type 2  Total  HP  Attack  Defense  \
# #
# 1                  Bulbasaur  Grass  Poison    318  45      49       49
# 2                    Ivysaur  Grass  Poison    405  60      62       63
# 3                   Venusaur  Grass  Poison    525  80      82       83
# 3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4                 Charmander   Fire     NaN    309  39      52       43
# 5                 Charmeleon   Fire     NaN    405  58      64       58
# 6                  Charizard   Fire  Flying    534  78      84       78
# 6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# 1       65       65     45           1      False
# 2       80       80     60           1      False
# ...

# %%
archivodos = "data/pokemon2.csv"
pokemondos = pd.read_csv(archivodos)

# %%
# Siguiente dataset...
pokemondos.head()
# Out:
#    Pokemon Id  Pokedex Number Pokemon Name  Classification  \
# 0           1               1  "Bulbasaur"  "Seed Pokémon"
# 1           2               2    "Ivysaur"  "Seed Pokémon"
# 2           3               3   "Venusaur"  "Seed Pokémon"
# 3           4               3   "Venusaur"  "Seed Pokémon"
# 4        1526               3   "Venusaur"  "Seed Pokémon"
#
#   Alternate Form Name  Original Pokemon ID Legendary Type  Pokemon Height  \
# 0                 NaN                  NaN            NaN             0.7
# 1                 NaN                  NaN            NaN             1.0
# 2                 NaN                  NaN            NaN             2.0
# 3              "Mega"                  3.0            NaN             2.4
# 4        "Gigantamax"                  3.0            NaN            24.0
#
#    Pokemon Weight Primary Type  ... Speed EV EV Yield Total Catch Rate  \
# 0             6.9      "Grass"  ...        0              1         45
# ...

# %%
archivotres = "data/pokemon3.csv"
pokemontres = pd.read_csv(archivotres)

# %%
# Siguiente dataset...
pokemontres.head()
# Out:
#    Unnamed: 0  pokedex_number           name german_name        japanese_name  \
# 0           0               1      Bulbasaur     Bisasam  フシギダネ (Fushigidane)
# 1           1               2        Ivysaur   Bisaknosp   フシギソウ (Fushigisou)
# 2           2               3       Venusaur    Bisaflor  フシギバナ (Fushigibana)
# 3           3               3  Mega Venusaur    Bisaflor  フシギバナ (Fushigibana)
# 4           4               4     Charmander    Glumanda      ヒトカゲ (Hitokage)
#
#    generation  status         species  type_number type_1  ... against_ground  \
# 0           1  Normal    Seed Pokémon            2  Grass  ...            1.0
# 1           1  Normal    Seed Pokémon            2  Grass  ...            1.0
# 2           1  Normal    Seed Pokémon            2  Grass  ...            1.0
# 3           1  Normal    Seed Pokémon            2  Grass  ...            1.0
# 4           1  Normal  Lizard Pokémon            1   Fire  ...            2.0
#
# ...

# %%
archivocuatro = "data/pokemon4.csv"
pokemoncuatro = pd.read_csv(archivocuatro)

# %%
# Siguiente dataset...
pokemoncuatro.head()
# Out:
#    dexnum        name  generation  type1   type2         species  height  \
# 0       1   Bulbasaur           1  Grass  Poison    Seed Pokémon     0.7
# 1       2     Ivysaur           1  Grass  Poison    Seed Pokémon     1.0
# 2       3    Venusaur           1  Grass  Poison    Seed Pokémon     2.0
# 3       4  Charmander           1   Fire     NaN  Lizard Pokémon     0.6
# 4       5  Charmeleon           1   Fire     NaN   Flame Pokémon     1.1
#
#    weight  ability1     ability2  ... catch_rate  base_friendship  base_exp  \
# 0     6.9  Overgrow  Chlorophyll  ...         45               50        64
# 1    13.0  Overgrow  Chlorophyll  ...         45               50       142
# 2   100.0  Overgrow  Chlorophyll  ...         45               50       236
# 3     8.5     Blaze  Solar Power  ...         45               50        62
# 4    19.0     Blaze  Solar Power  ...         45               50       142
#
# ...

# %%
pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 800 entries, 1 to 721
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        800 non-null    object
#  1   Type 1      800 non-null    object
#  2   Type 2      414 non-null    object
#  3   Total       800 non-null    int64
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 75.8+ KB

# %% [markdown]
# ### Comienzo la filtracion de datos, extrayendo las megaevoluciones

# %%
pokemega = pokemon.loc[pokemon["Name"].str.contains(r'Mega\b', na=False)]
pokemega
# Out:
#                           Name    Type 1    Type 2  Total   HP  Attack  \
# #
# 3        VenusaurMega Venusaur     Grass    Poison    625   80     100
# 6    CharizardMega Charizard X      Fire    Dragon    634   78     130
# 6    CharizardMega Charizard Y      Fire    Flying    634   78     104
# 9      BlastoiseMega Blastoise     Water       NaN    630   79     103
# 15       BeedrillMega Beedrill       Bug    Poison    495   65     150
# 18         PidgeotMega Pidgeot    Normal    Flying    579   83      80
# 65       AlakazamMega Alakazam   Psychic       NaN    590   55      50
# 80         SlowbroMega Slowbro     Water   Psychic    590   95      75
# 94           GengarMega Gengar     Ghost    Poison    600   60      65
# 115  KangaskhanMega Kangaskhan    Normal       NaN    590  105     125
# 127          PinsirMega Pinsir       Bug    Flying    600   65     155
# 130      GyaradosMega Gyarados     Water      Dark    640   95     155
# ...

# %%
pokenomega = pokemon.loc[~pokemon["Name"].str.contains(r'Mega\b', na=False)]
pokenomega
# Out:
#                     Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# #
# 1              Bulbasaur    Grass  Poison    318   45      49       49
# 2                Ivysaur    Grass  Poison    405   60      62       63
# 3               Venusaur    Grass  Poison    525   80      82       83
# 4             Charmander     Fire     NaN    309   39      52       43
# 5             Charmeleon     Fire     NaN    405   58      64       58
# ..                   ...      ...     ...    ...  ...     ...      ...
# 718     Zygarde50% Forme   Dragon  Ground    600  108     100      121
# 719              Diancie     Rock   Fairy    600   50     100      150
# 720  HoopaHoopa Confined  Psychic   Ghost    600   80     110       60
# 720   HoopaHoopa Unbound  Psychic    Dark    680   80     160       60
# 721            Volcanion     Fire   Water    600   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# 1         65       65     45           1      False
# ...

# %% [markdown]
# ### Ahora quito los legendarios

# %%
pokemonlegen = pokenomega[pokenomega["Legendary"] == True]
pokemonlegen
# Out:
#                          Name    Type 1    Type 2  Total   HP  Attack  \
# #
# 144                  Articuno       Ice    Flying    580   90      85
# 145                    Zapdos  Electric    Flying    580   90      90
# 146                   Moltres      Fire    Flying    580   90     100
# 150                    Mewtwo   Psychic       NaN    680  106     110
# 243                    Raikou  Electric       NaN    580   90      85
# 244                     Entei      Fire       NaN    580  115     115
# 245                   Suicune     Water       NaN    580  100      75
# 249                     Lugia   Psychic    Flying    680  106      90
# 250                     Ho-oh      Fire    Flying    680  106     130
# 377                  Regirock      Rock       NaN    580   80     100
# 378                    Regice       Ice       NaN    580   80      50
# 379                 Registeel     Steel       NaN    580   80      75
# ...

# %%
pokemonlegen["Total"].mean()
# Out:
# 626.9491525423729

# %%
pokemonlegen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 59 entries, 144 to 721
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        59 non-null     object
#  1   Type 1      59 non-null     object
#  2   Type 2      35 non-null     object
#  3   Total       59 non-null     int64
#  4   HP          59 non-null     int64
#  5   Attack      59 non-null     int64
#  6   Defense     59 non-null     int64
#  7   Sp. Atk     59 non-null     int64
#  8   Sp. Def     59 non-null     int64
#  9   Speed       59 non-null     int64
#  10  Generation  59 non-null     int64
#  11  Legendary   59 non-null     bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 5.6+ KB

# %%
pokemonlegen["Total"].mean()
# Out:
# 626.9491525423729

# %%
pokemonlegen["Total"].max()
# Out:
# 770

# %%
pokemonlegen["Total"].idxmax()
# Out:
# 382

# %%
pokemonlegen[pokemonlegen["Total"] == pokemonlegen["Total"].max()]
# Out:
#                       Name  Type 1 Type 2  Total   HP  Attack  Defense  \
# #
# 382    KyogrePrimal Kyogre   Water    NaN    770  100     150       90
# 383  GroudonPrimal Groudon  Ground   Fire    770  100     180      160
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# 382      180      160     90           3       True
# 383      150       90     90           3       True

# %%
pokefilt = pokenomega[pokenomega["Legendary"] == False]
pokefilt
# Out:
#                     Name  Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# #
# 1              Bulbasaur   Grass  Poison    318  45      49       49       65
# 2                Ivysaur   Grass  Poison    405  60      62       63       80
# 3               Venusaur   Grass  Poison    525  80      82       83      100
# 4             Charmander    Fire     NaN    309  39      52       43       60
# 5             Charmeleon    Fire     NaN    405  58      64       58       80
# ..                   ...     ...     ...    ...  ..     ...      ...      ...
# 711  GourgeistSuper Size   Ghost   Grass    494  85     100      122       58
# 712             Bergmite     Ice     NaN    304  55      69       85       32
# 713              Avalugg     Ice     NaN    514  95     117      184       44
# 714               Noibat  Flying  Dragon    245  40      30       35       45
# 715              Noivern  Flying  Dragon    535  85      70       80       97
#
# ...

# %%
pokefilt["Total"].mean()
# Out:
# 406.1327561327561

# %%
pokefilt["Total"].max()
# Out:
# 670

# %%
pokefilt["Total"].idxmax()
# Out:
# 289

# %%
pokefilt[pokefilt["Total"] == pokefilt["Total"].max()]
# Out:
#         Name  Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 289  Slaking  Normal    NaN    670  150     160      100       95       65
#
#      Speed  Generation  Legendary
# #
# 289    100           3      False

# %%
pokefilt["Type 1"].describe()
# Out:
# count       693
# unique       18
# top       Water
# freq        103
# Name: Type 1, dtype: object

# %%
pokefilt.groupby("Type 1")[["Total","Attack","Defense","Sp. Atk","Sp. Def","Speed"]].agg(["mean","median","max"])
# Out:
#                Total                 Attack                 Defense         \
#                 mean median  max       mean median  max        mean median
# Type 1
# Bug       366.938462  390.0  600  65.492308   65.0  135   68.692308   59.0
# Dark      418.961538  425.0  600  84.384615   85.0  130   66.038462   62.5
# Dragon    443.941176  420.0  600  96.647059   90.0  147   71.058824   70.0
# Electric  421.184211  435.5  540  65.131579   64.0  123   64.000000   60.0
# Fairy     396.500000  388.0  552  57.187500   51.0  120   63.875000   65.5
# Fighting  404.360000  455.0  525  94.720000  100.0  140   64.280000   62.0
# Fire      426.093023  410.0  555  77.883721   76.0  140   61.953488   58.0
# Flying    390.000000  390.0  535  50.000000   50.0   70   57.500000   57.5
# Ghost     412.535714  445.0  525  68.250000   66.0  115   79.392857   70.0
# Grass     403.921875  405.0  535  70.156250   67.5  130   68.843750   65.0
# ...

# %%
pokefilt
# Out:
#                     Name  Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# #
# 1              Bulbasaur   Grass  Poison    318  45      49       49       65
# 2                Ivysaur   Grass  Poison    405  60      62       63       80
# 3               Venusaur   Grass  Poison    525  80      82       83      100
# 4             Charmander    Fire     NaN    309  39      52       43       60
# 5             Charmeleon    Fire     NaN    405  58      64       58       80
# ..                   ...     ...     ...    ...  ..     ...      ...      ...
# 711  GourgeistSuper Size   Ghost   Grass    494  85     100      122       58
# 712             Bergmite     Ice     NaN    304  55      69       85       32
# 713              Avalugg     Ice     NaN    514  95     117      184       44
# 714               Noibat  Flying  Dragon    245  40      30       35       45
# 715              Noivern  Flying  Dragon    535  85      70       80       97
#
# ...

# %%
pokefilt.groupby("Type 1")["Total"].agg(["mean","median","max"])
# Out:
#                 mean  median  max
# Type 1
# Bug       366.938462   390.0  600
# Dark      418.961538   425.0  600
# Dragon    443.941176   420.0  600
# Electric  421.184211   435.5  540
# Fairy     396.500000   388.0  552
# Fighting  404.360000   455.0  525
# Fire      426.093023   410.0  555
# Flying    390.000000   390.0  535
# Ghost     412.535714   445.0  525
# Grass     403.921875   405.0  535
# Ground    405.714286   415.0  535
# Ice       412.523810   450.0  535
# Normal    387.836957   410.5  670
# Poison    399.142857   401.5  535
# Psychic   409.075000   415.0  600
# Rock      426.052632   410.0  600
# Steel     437.263158   448.0  600
# Water     412.194175   430.0  600

# %%
pokefilt.describe()
# Out:
#             Total          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  693.000000  693.000000  693.000000  693.000000  693.000000  693.000000
# mean   406.132756   66.594517   72.825397   69.411255   66.174603   67.194805
# std     98.882015   25.184437   27.878345   28.445003   26.710011   25.107707
# min    180.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    318.000000   50.000000   52.000000   50.000000   45.000000   50.000000
# 50%    413.000000   64.000000   70.000000   65.000000   61.000000   65.000000
# 75%    490.000000   78.000000   90.000000   85.000000   85.000000   80.000000
# max    670.000000  255.000000  165.000000  230.000000  150.000000  230.000000
#
#             Speed  Generation
# count  693.000000  693.000000
# mean    63.932179    3.337662
# std     26.532503    1.686819
# min      5.000000    1.000000
# 25%     45.000000    2.000000
# 50%     60.000000    3.000000
# 75%     84.000000    5.000000
# ...

# %%
pokefilt[pokefilt["Total"] == pokefilt["Total"].max()]
# Out:
#         Name  Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 289  Slaking  Normal    NaN    670  150     160      100       95       65
#
#      Speed  Generation  Legendary
# #
# 289    100           3      False

# %%
pokefilt[pokefilt["HP"] == pokefilt["HP"].max()]
# Out:
#         Name  Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 242  Blissey  Normal    NaN    540  255      10       10       75      135
#
#      Speed  Generation  Legendary
# #
# 242     55           2      False

# %%
pokefilt[pokefilt["Attack"] == pokefilt["Attack"].max()]
# Out:
#           Name Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 409  Rampardos   Rock    NaN    495  97     165       60       65       50
#
#      Speed  Generation  Legendary
# #
# 409     58           4      False

# %%
pokefilt[pokefilt["Defense"] == pokefilt["Defense"].max()]
# Out:
#         Name Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 213  Shuckle    Bug   Rock    505  20      10      230       10      230
#
#      Speed  Generation  Legendary
# #
# 213      5           2      False

# %%
pokefilt[pokefilt["Sp. Atk"] == pokefilt["Sp. Atk"].max()]
# Out:
#                      Name Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# #
# 681  AegislashBlade Forme  Steel  Ghost    520  60     150       50      150
#
#      Sp. Def  Speed  Generation  Legendary
# #
# 681       50     60           6      False

# %%
pokefilt[pokefilt["Sp. Def"] == pokefilt["Sp. Def"].max()]
# Out:
#         Name Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 213  Shuckle    Bug   Rock    505  20      10      230       10      230
#
#      Speed  Generation  Legendary
# #
# 213      5           2      False

# %%
pokewater = pokefilt[(pokefilt['Type 1'] == "Water") | (pokefilt['Type 2'] == "Water")]
pokewater
# Out:
#            Name  Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 7      Squirtle   Water    NaN    314  44      48       65       50       64
# 8     Wartortle   Water    NaN    405  59      63       80       65       80
# 9     Blastoise   Water    NaN    530  79      83      100       85      105
# 54      Psyduck   Water    NaN    320  50      52       48       65       50
# 55      Golduck   Water    NaN    500  80      82       78       95       80
# ..          ...     ...    ...    ...  ..     ...      ...      ...      ...
# 688     Binacle    Rock  Water    306  42      52       67       39       56
# 689  Barbaracle    Rock  Water    500  72     105      115       54       86
# 690      Skrelp  Poison  Water    320  50      60       60       60       60
# 692   Clauncher   Water    NaN    330  50      53       62       58       63
# 693   Clawitzer   Water    NaN    500  71      73       88      120       89
#
#      Speed  Generation  Legendary
# #
# ...

# %%
pokefire = pokefilt[(pokefilt['Type 1'] == "Fire") | (pokefilt['Type 2'] == "Fire")]
pokefire
# Out:
#                         Name    Type 1    Type 2  Total   HP  Attack  Defense  \
# #
# 4                 Charmander      Fire       NaN    309   39      52       43
# 5                 Charmeleon      Fire       NaN    405   58      64       58
# 6                  Charizard      Fire    Flying    534   78      84       78
# 37                    Vulpix      Fire       NaN    299   38      41       40
# 38                 Ninetales      Fire       NaN    505   73      76       75
# 58                 Growlithe      Fire       NaN    350   55      70       45
# 59                  Arcanine      Fire       NaN    555   90     110       80
# 77                    Ponyta      Fire       NaN    410   50      85       55
# 78                  Rapidash      Fire       NaN    500   65     100       70
# 126                   Magmar      Fire       NaN    495   65      95       57
# 136                  Flareon      Fire       NaN    525   65     130       60
# ...

# %%
pokebug = pokefilt[(pokefilt['Type 1'] == "Bug") | (pokefilt['Type 2'] == "Bug")]
pokebug
# Out:
#            Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 10     Caterpie    Bug     NaN    195  45      30       35       20       20
# 11      Metapod    Bug     NaN    205  50      20       55       25       25
# 12   Butterfree    Bug  Flying    395  60      45       50       90       80
# 13       Weedle    Bug  Poison    195  40      35       30       20       20
# 14       Kakuna    Bug  Poison    205  45      25       50       25       25
# ..          ...    ...     ...    ...  ..     ...      ...      ...      ...
# 637   Volcarona    Bug    Fire    550  85      60       65      135      105
# 649    Genesect    Bug   Steel    600  71     120       95      120       95
# 664  Scatterbug    Bug     NaN    200  38      35       40       27       25
# 665      Spewpa    Bug     NaN    213  45      22       60       27       30
# 666    Vivillon    Bug  Flying    411  80      52       50       90       50
#
#      Speed  Generation  Legendary
# #
# ...

# %%
pokedragon = pokefilt[(pokefilt['Type 1'] == "Dragon") | (pokefilt['Type 2'] == "Dragon")]
pokedragon
# Out:
#           Name  Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 147    Dratini  Dragon     NaN    300   41      64       45       50       50
# 148  Dragonair  Dragon     NaN    420   61      84       65       70       70
# 149  Dragonite  Dragon  Flying    600   91     134       95      100      100
# 230    Kingdra   Water  Dragon    540   75      95       95       95       95
# 329    Vibrava  Ground  Dragon    340   50      70       50       50       50
# 330     Flygon  Ground  Dragon    520   80     100       80       80       80
# 334    Altaria  Dragon  Flying    490   75      70       90       70      105
# 371      Bagon  Dragon     NaN    300   45      75       60       40       30
# 372    Shelgon  Dragon     NaN    420   65      95      100       60       50
# 373  Salamence  Dragon  Flying    600   95     135       80      110       80
# 443      Gible  Dragon  Ground    300   58      70       45       40       45
# ...

# %%
pokefilt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 693 entries, 1 to 715
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        693 non-null    object
#  1   Type 1      693 non-null    object
#  2   Type 2      340 non-null    object
#  3   Total       693 non-null    int64
#  4   HP          693 non-null    int64
#  5   Attack      693 non-null    int64
#  6   Defense     693 non-null    int64
#  7   Sp. Atk     693 non-null    int64
#  8   Sp. Def     693 non-null    int64
#  9   Speed       693 non-null    int64
#  10  Generation  693 non-null    int64
#  11  Legendary   693 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 65.6+ KB

# %%
pokefilt["Total"].mean()
# Out:
# 406.1327561327561

# %%
pokefilt["Total"].max()
# Out:
# 670

# %%
pokeelectric = pokefilt[(pokefilt['Type 1'] == "Electric") | (pokefilt['Type 2'] == "Electric")]
pokeelectric
# Out:
#                  Name    Type 1    Type 2  Total   HP  Attack  Defense  \
# #
# 25            Pikachu  Electric       NaN    320   35      55       40
# 26             Raichu  Electric       NaN    485   60      90       55
# 81          Magnemite  Electric     Steel    325   25      35       70
# 82           Magneton  Electric     Steel    465   50      60       95
# 100           Voltorb  Electric       NaN    330   40      30       50
# 101         Electrode  Electric       NaN    480   60      50       70
# 125        Electabuzz  Electric       NaN    490   65      83       57
# 135           Jolteon  Electric       NaN    525   65      65       60
# 170          Chinchou     Water  Electric    330   75      38       38
# 171           Lanturn     Water  Electric    460  125      58       58
# 172             Pichu  Electric       NaN    205   20      40       15
# 179            Mareep  Electric       NaN    280   55      40       40
# ...

# %%
pokepsychic = pokefilt[(pokefilt['Type 1'] == "Psychic") | (pokefilt['Type 2'] == "Psychic")]
pokepsychic
# Out:
#                Name   Type 1   Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# #
# 63             Abra  Psychic      NaN    310  25      20       15      105
# 64          Kadabra  Psychic      NaN    400  40      35       30      120
# 65         Alakazam  Psychic      NaN    500  55      50       45      135
# 79         Slowpoke    Water  Psychic    315  90      65       65       40
# 80          Slowbro    Water  Psychic    490  95      75      110      100
# ..              ...      ...      ...    ...  ..     ...      ...      ...
# 677          Espurr  Psychic      NaN    355  62      48       54       63
# 678    MeowsticMale  Psychic      NaN    466  74      48       76       83
# 678  MeowsticFemale  Psychic      NaN    466  74      48       76       83
# 686           Inkay     Dark  Psychic    288  53      54       53       37
# 687         Malamar     Dark  Psychic    482  86      92       88       68
#
#      Sp. Def  Speed  Generation  Legendary
# #
# ...

# %%
pokefiltnodrag = pokefilt[~((pokefilt['Type 1'] == "Dragon") | (pokefilt['Type 2'] == "Dragon"))]
pokefiltnodrag
# Out:
#                     Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# #
# 1              Bulbasaur  Grass  Poison    318  45      49       49       65
# 2                Ivysaur  Grass  Poison    405  60      62       63       80
# 3               Venusaur  Grass  Poison    525  80      82       83      100
# 4             Charmander   Fire     NaN    309  39      52       43       60
# 5             Charmeleon   Fire     NaN    405  58      64       58       80
# ..                   ...    ...     ...    ...  ..     ...      ...      ...
# 711  GourgeistSmall Size  Ghost   Grass    494  55      85      122       58
# 711  GourgeistLarge Size  Ghost   Grass    494  75      95      122       58
# 711  GourgeistSuper Size  Ghost   Grass    494  85     100      122       58
# 712             Bergmite    Ice     NaN    304  55      69       85       32
# 713              Avalugg    Ice     NaN    514  95     117      184       44
#
# ...

# %% [markdown]
# ### Obtengo los valores de los pokemon que voy a analizar

# %%
pikachu = pokefilt[pokefilt["Name"].str.contains("Pikachu")]
pikachu
# Out:
#        Name    Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 25  Pikachu  Electric    NaN    320  35      55       40       50       50
#
#     Speed  Generation  Legendary
# #
# 25     90           1      False

# %%
dragonite = pokefilt[pokefilt["Name"].str.contains("Dragonite")]
dragonite
# Out:
#           Name  Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 149  Dragonite  Dragon  Flying    600  91     134       95      100      100
#
#      Speed  Generation  Legendary
# #
# 149     80           1      False

# %%
charizard = pokefilt[pokefilt["Name"].str.contains("Charizard")]
charizard
# Out:
#         Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 6  Charizard   Fire  Flying    534  78      84       78      109       85
#
#    Speed  Generation  Legendary
# #
# 6    100           1      False

# %%
raichu = pokefilt[pokefilt["Name"].str.contains("Raichu")]
raichu
# Out:
#       Name    Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 26  Raichu  Electric    NaN    485  60      90       55       90       80
#
#     Speed  Generation  Legendary
# #
# 26    110           1      False

# %%
scizor = pokefilt[pokefilt["Name"].str.contains("Scizor")]
scizor
# Out:
#        Name Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 212  Scizor    Bug  Steel    500  70     130      100       55       80
#
#      Speed  Generation  Legendary
# #
# 212     65           2      False

# %%
squirtle = pokefilt[pokefilt["Name"].str.contains("Squirtle")]
squirtle
# Out:
#        Name Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 7  Squirtle  Water    NaN    314  44      48       65       50       64
#
#    Speed  Generation  Legendary
# #
# 7     43           1      False

# %%
blastoise = pokefilt[pokefilt["Name"].str.contains("Blastoise")]
blastoise
# Out:
#         Name Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 9  Blastoise  Water    NaN    530  79      83      100       85      105
#
#    Speed  Generation  Legendary
# #
# 9     78           1      False

# %%
gyarados = pokefilt[pokefilt["Name"].str.contains("Gyarados")]
gyarados
# Out:
#          Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 130  Gyarados  Water  Flying    540  95     125       79       60      100
#
#      Speed  Generation  Legendary
# #
# 130     81           1      False

# %%
magikarp = pokefilt[pokefilt["Name"].str.contains("Magikarp")]
magikarp
# Out:
#          Name Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 129  Magikarp  Water    NaN    200  20      10       55       15       20
#
#      Speed  Generation  Legendary
# #
# 129     80           1      False

# %%
mewtwo = pokemonlegen[pokemonlegen["Name"].str.contains("Mewtwo")]
mewtwo
# Out:
#        Name   Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 150  Mewtwo  Psychic    NaN    680  106     110       90      154       90
#
#      Speed  Generation  Legendary
# #
# 150    130           1       True

# %%
pokefilt.loc[37]
# Out:
# Name          Vulpix
# Type 1          Fire
# Type 2           NaN
# Total            299
# HP                38
# Attack            41
# Defense           40
# Sp. Atk           50
# Sp. Def           65
# Speed             65
# Generation         1
# Legendary      False
# Name: 37, dtype: object

# %% [markdown]
# ### Comienzo a analizar los tipos para el analisis del tipo dragon

# %%
value_counts_col1 = pokefilt["Type 1"].value_counts()
value_counts_col2 = pokefilt["Type 2"].value_counts()
dfTipos = pd.concat([value_counts_col1, value_counts_col2,value_counts_col1+value_counts_col2], axis=1)
dfTipos.columns = ["Type 1", "Type 2", "Total"]
dfTipos
# Out:
#           Type 1  Type 2  Total
# Water        103      13    116
# Normal        92       4     96
# Bug           65       3     68
# Grass         64      25     89
# Fire          43       8     51
# Psychic       40      25     65
# Electric      38       5     43
# Rock          38      14     52
# Ghost         28      12     40
# Poison        28      31     59
# Ground        28      30     58
# Dark          26      16     42
# Fighting      25      18     43
# Ice           21      10     31
# Steel         19      19     38
# Dragon        17      11     28
# Fairy         16      17     33
# Flying         2      79     81

# %% [markdown]
# ### Despues de analizar, me dispongo a sacar graficas para explicar mis conclusiones

# %%
pokemon_type_colors = {
    'Bug': '#A8B820',
    'Dark': '#705848',
    'Dragon': '#7038F8',
    'Electric': '#F8D030', 
    'Fairy': '#EE99AC',
    'Fighting': '#C03028',
    'Fire': '#F08030',
    'Flying': '#A890F0',
    'Ghost': '#705898',
    'Grass': '#78C850',
    'Ground': '#E0C068',
    'Ice': '#98D8D8',
    'Normal': '#A8A878',
    'Poison': '#A040A0',
    'Psychic': '#F85888',
    'Rock': '#B8A038',
    'Steel': '#B8B8D0',
    'Water': '#6890F0'
}

# %%
colors = [pokemon_type_colors[tipo] for tipo in dfTipos.index]
ordered_df = dfTipos.sort_values(by='Total', ascending=False)

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x=ordered_df.index, y=ordered_df["Total"], palette=colors, order=ordered_df.index)
plt.xticks(rotation=-45)
plt.title('Conteo Total de Tipos de Pokémon')
plt.xlabel('Tipo de Pokémon')
plt.ylabel('Conteo');

# %%
plt.figure(figsize=(8, 8))
dfTipos['Total'].plot(kind='pie', labels=dfTipos.index, autopct='%1.0f%%', legend=False,colors=colors)
plt.title("Porcentaje de Tipos de Pokémon")
plt.ylabel("")
# Out:
# Text(0, 0.5, '')

# %%
plt.figure(figsize=(10,5))
sns.boxplot(y="Total", data=pokefilt,  palette="pastel")
sns.swarmplot(y="Total", data=pokefilt, palette="colorblind")
plt.title("Pokemon aptos para competitivo")
plt.xlabel("EDA Pokemon");

# %%
plt.figure(figsize=(10,5))
sns.boxplot(y="Total", data=pokefilt,  palette="pastel")
sns.swarmplot(y="Total", data=pokefilt, palette="colorblind")
sns.swarmplot(y="Total", data=pikachu, color='red', label='Pikachu')
sns.swarmplot(y="Total", data=raichu, color='black', label='Raichu')
plt.title("Pokemon aptos para competitivo")
plt.xlabel("EDA Pokemon");

# %%
plt.figure(figsize=(10,5))
sns.boxplot(y="Total", data=pokefiltnodrag,  palette="pastel")
sns.swarmplot(y="Total", data=pokedragon, palette="colorblind")
sns.swarmplot(y="Total", data=dragonite, color='red', label='Dragonite')
plt.title("Pokemon Dragon vs Resto")
plt.xlabel("EDA Pokemon");

# %%
plt.figure(figsize=(10,5))
sns.boxplot(y="Total", data=pokefiltnodrag,  palette="pastel")
sns.swarmplot(y="Total", data=pokefilt, palette="colorblind")
sns.swarmplot(y="Total", data=mewtwo, color='black', label='mewtwo')
plt.title("Pokemon Dragon vs Resto")
plt.xlabel("EDA Pokemon");

# %%
plt.figure(figsize=(10,5))
sns.swarmplot(y="Total", data=pokefilt,  palette="pastel")
sns.swarmplot(y="Total", data=pokedragon, color="black")
plt.title("Pokemon Dragon vs resto")
plt.xlabel("EDA Pokemon");

# %%
plt.figure(figsize=(10,5))
sns.boxplot(y="Total", data=pokefiltnodrag,  palette="pastel")
sns.boxplot(y="Total", data=pokedragon, color="yellow")
plt.title("Pokemon Dragon vs resto")
plt.xlabel("Diagrama de caja");

# %%
plt.figure(figsize=(5,5))
sns.boxplot(y="Total", data=pokedragon, color="#7038F8")
plt.title("Pokemon Dragon")
plt.xlabel("EDA Pokemon");

# %%
plt.figure(figsize=(5,5))
sns.boxplot(y="Total", data=pokefiltnodrag,  palette="pastel")
plt.title("Pokemon de todo tipo menos dragon")
plt.xlabel("EDA Pokemon");

# %%
plt.figure(figsize=(10,5))
sns.boxplot(y="Total", data=pokefiltnodrag,  palette="pastel")
sns.boxplot(y="Total", data=pokedragon, color="grey" )
plt.title("Pokemon Dragon vs resto")
plt.xlabel("Diagrama de caja");

# %%
plt.figure(figsize=(10,5))
sns.boxplot(y="Total", data=pokeelectric, color="yellow")
sns.swarmplot(y="Total", data=pikachu, color='red', label='Pikachu')
sns.swarmplot(y="Total", data=raichu, color='black', label='Raichu')
plt.title("Pokemon Tipo electrico")
plt.xlabel("EDA Pokemon");

# %%
plt.figure(figsize=(10,5))
sns.boxplot(y="Total", data=pokebug, color="limegreen")
sns.swarmplot(y="Total", data=scizor, color='red', label='Scizor')
plt.title("Pokemon Tipo bicho")
plt.xlabel("Diagrama de caja");

# %%
plt.figure(figsize=(10,5))
sns.boxplot(y="Total", data=pokeelectric, color="yellow")
sns.swarmplot(y="Total", data=pikachu, color='red', label='Pikachu')
plt.title("Pokemon Tipo electrico")
plt.xlabel("EDA pokemon");

# %%
plt.figure(figsize=(10,5))
sns.boxplot(y="Total", data=pokewater, color="blue")
sns.swarmplot(y="Total", data=gyarados, color='black', label='Gyarados')
sns.swarmplot(y="Total", data=blastoise, color='red', label='Blastoise')
sns.swarmplot(y="Total", data=squirtle, color='purple', label='Squirtle')
sns.swarmplot(y="Total", data=magikarp, color='yellow', label='Magikarp')
plt.title("Pokemon Tipo Agua")
plt.xlabel("EDA Pokemon");

# %%
plt.figure(figsize=(10,5))
sns.boxplot(y="Total", data=pokedragon, palette="pastel")
sns.swarmplot(y="Total", data=pokedragon, color='brown', label='Tipo dragon')
sns.swarmplot(y="Total", data=dragonite, color='black', label='Dragonite')
plt.title("Pokemon Tipo Dragon")
plt.xlabel("EDA Pokemon");

# %%
plt.figure(figsize=(10,5))
chart = sns.catplot(x="Type 1", y="Total", data=pokefilt, hue="Type 2", col="Generation")
chart.set_xticklabels(rotation=-45)

# %%
plt.figure(figsize=(10,5))
sns.boxplot(y="Total", data=pokefire, color="red")
sns.swarmplot(y="Total", data=charizard, color='black', label='Charizard')
plt.title("Pokemon Tipo Fuego")
plt.xlabel("EDA Pokemon");

# %%
pokerelleno =  pokefilt
pokerelleno
# Out:
#                     Name  Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# #
# 1              Bulbasaur   Grass  Poison    318  45      49       49       65
# 2                Ivysaur   Grass  Poison    405  60      62       63       80
# 3               Venusaur   Grass  Poison    525  80      82       83      100
# 4             Charmander    Fire     NaN    309  39      52       43       60
# 5             Charmeleon    Fire     NaN    405  58      64       58       80
# ..                   ...     ...     ...    ...  ..     ...      ...      ...
# 711  GourgeistSuper Size   Ghost   Grass    494  85     100      122       58
# 712             Bergmite     Ice     NaN    304  55      69       85       32
# 713              Avalugg     Ice     NaN    514  95     117      184       44
# 714               Noibat  Flying  Dragon    245  40      30       35       45
# 715              Noivern  Flying  Dragon    535  85      70       80       97
#
# ...

# %%
pokerelleno['Type 2'].fillna("No type", inplace=True)

# %%
pokerellenogen1 = pokerelleno[(pokerelleno['Generation'] == 1)]
pokerellenogen1
# Out:
#            Name   Type 1   Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# #
# 1     Bulbasaur    Grass   Poison    318   45      49       49       65
# 2       Ivysaur    Grass   Poison    405   60      62       63       80
# 3      Venusaur    Grass   Poison    525   80      82       83      100
# 4    Charmander     Fire  No type    309   39      52       43       60
# 5    Charmeleon     Fire  No type    405   58      64       58       80
# ..          ...      ...      ...    ...  ...     ...      ...      ...
# 143     Snorlax   Normal  No type    540  160     110       65       65
# 147     Dratini   Dragon  No type    300   41      64       45       50
# 148   Dragonair   Dragon  No type    420   61      84       65       70
# 149   Dragonite   Dragon   Flying    600   91     134       95      100
# 151         Mew  Psychic  No type    600  100     100      100      100
#
#      Sp. Def  Speed  Generation  Legendary
# #
# 1         65     45           1      False
# ...

# %%
plt.figure(figsize=(10,5))
chart = sns.catplot(x="Type 1", y="Total", data=pokerellenogen1, hue="Type 2", col="Generation")
chart.set_xticklabels(rotation=-45)

# %%
pokerellenogen2 = pokerelleno[(pokerelleno['Generation'] == 2)]
pokerellenogen2
# Out:
#           Name   Type 1   Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# #
# 152  Chikorita    Grass  No type    318   45      49       65       49
# 153    Bayleef    Grass  No type    405   60      62       80       63
# 154   Meganium    Grass  No type    525   80      82      100       83
# 155  Cyndaquil     Fire  No type    309   39      52       43       60
# 156    Quilava     Fire  No type    405   58      64       58       80
# ..         ...      ...      ...    ...  ...     ...      ...      ...
# 242    Blissey   Normal  No type    540  255      10       10       75
# 246   Larvitar     Rock   Ground    300   50      64       50       45
# 247    Pupitar     Rock   Ground    410   70      84       70       65
# 248  Tyranitar     Rock     Dark    600  100     134      110       95
# 251     Celebi  Psychic    Grass    600  100     100      100      100
#
#      Sp. Def  Speed  Generation  Legendary
# #
# 152       65     45           2      False
# ...

# %%
plt.figure(figsize=(10,5))
chart = sns.catplot(x="Type 1", y="Total", data=pokerellenogen2, hue="Type 2", col="Generation")
chart.set_xticklabels(rotation=-45);

# %%
pokerellenogen3 = pokerelleno[(pokerelleno['Generation'] == 3)]
pokerellenogen3
# Out:
#           Name  Type 1    Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# #
# 252    Treecko   Grass   No type    310  40      45       35       65
# 253    Grovyle   Grass   No type    405  50      65       45       85
# 254   Sceptile   Grass   No type    530  70      85       65      105
# 255    Torchic    Fire   No type    310  45      60       40       70
# 256  Combusken    Fire  Fighting    405  60      85       60       85
# ..         ...     ...       ...    ...  ..     ...      ...      ...
# 372    Shelgon  Dragon   No type    420  65      95      100       60
# 373  Salamence  Dragon    Flying    600  95     135       80      110
# 374     Beldum   Steel   Psychic    300  40      55       80       35
# 375     Metang   Steel   Psychic    420  60      75      100       55
# 376  Metagross   Steel   Psychic    600  80     135      130       95
#
#      Sp. Def  Speed  Generation  Legendary
# #
# 252       55     70           3      False
# ...

# %%
plt.figure(figsize=(10,5))
chart = sns.catplot(x="Type 1", y="Total", data=pokerellenogen3, hue="Type 2", col="Generation")
chart.set_xticklabels(rotation=-45);

# %%
pokerellenogen4 = pokerelleno[(pokerelleno['Generation'] == 4)]
pokerellenogen4
# Out:
#                Name    Type 1    Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# #
# 387         Turtwig     Grass   No type    318   55      68       64       45
# 388          Grotle     Grass   No type    405   75      89       85       55
# 389        Torterra     Grass    Ground    525   95     109      105       75
# 390        Chimchar      Fire   No type    309   44      58       44       58
# 391        Monferno      Fire  Fighting    405   64      78       52       78
# ..              ...       ...       ...    ...  ...     ...      ...      ...
# 479  RotomFan Rotom  Electric    Flying    520   50      65      107      105
# 479  RotomMow Rotom  Electric     Grass    520   50      65      107      105
# 488       Cresselia   Psychic   No type    600  120      70      120       75
# 489          Phione     Water   No type    480   80      80       80       80
# 490         Manaphy     Water   No type    600  100     100      100      100
#
# ...

# %%
plt.figure(figsize=(10,5))
chart = sns.catplot(x="Type 1", y="Total", data=pokerellenogen4, hue="Type 2", col="Generation")
chart.set_xticklabels(rotation=-45);

# %%
pokerellenogen5 = pokerelleno[(pokerelleno['Generation'] == 5)]
pokerellenogen5
# Out:
#                         Name  Type 1    Type 2  Total   HP  Attack  Defense  \
# #
# 495                    Snivy   Grass   No type    308   45      45       55
# 496                  Servine   Grass   No type    413   60      60       75
# 497                Serperior   Grass   No type    528   75      75       95
# 498                    Tepig    Fire   No type    308   65      63       45
# 499                  Pignite    Fire  Fighting    418   90      93       55
# ..                       ...     ...       ...    ...  ...     ...      ...
# 647     KeldeoOrdinary Forme   Water  Fighting    580   91      72       90
# 647     KeldeoResolute Forme   Water  Fighting    580   91      72       90
# 648       MeloettaAria Forme  Normal   Psychic    600  100      77       77
# 648  MeloettaPirouette Forme  Normal  Fighting    600  100     128       90
# 649                 Genesect     Bug     Steel    600   71     120       95
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
plt.figure(figsize=(10,5))
chart = sns.catplot(x="Type 1", y="Total", data=pokerellenogen5, hue="Type 2", col="Generation")
chart.set_xticklabels(rotation=-45);

# %%
pokerellenogen6 = pokerelleno[(pokerelleno['Generation'] == 6)]
pokerellenogen6
# Out:
#                     Name  Type 1    Type 2  Total  HP  Attack  Defense  \
# #
# 650              Chespin   Grass   No type    313  56      61       65
# 651            Quilladin   Grass   No type    405  61      78       95
# 652           Chesnaught   Grass  Fighting    530  88     107      122
# 653             Fennekin    Fire   No type    307  40      45       40
# 654              Braixen    Fire   No type    409  59      59       58
# ..                   ...     ...       ...    ...  ..     ...      ...
# 711  GourgeistSuper Size   Ghost     Grass    494  85     100      122
# 712             Bergmite     Ice   No type    304  55      69       85
# 713              Avalugg     Ice   No type    514  95     117      184
# 714               Noibat  Flying    Dragon    245  40      30       35
# 715              Noivern  Flying    Dragon    535  85      70       80
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# 650       48       45     38           6      False
# ...

# %%
plt.figure(figsize=(10,5))
chart = sns.catplot(x="Type 1", y="Total", data=pokerellenogen6, hue="Type 2", col="Generation")
chart.set_xticklabels(rotation=-45);
